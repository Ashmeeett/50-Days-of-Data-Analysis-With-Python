# %% [markdown]
# 1. Load the CSV dataset above. Check the "date" and "revenue" data types. Write another code to check for any duplicates in the "spare_parts" column. Use a histogram to visualize the distribution of total sales for the entire store. Do you notice any outliers in the histogram?

# %%
import pandas as pd

df = pd.read_csv("Datasets_50_Days_Of_Data_Analysis/spare_parts_expanded.csv")
df.head()
# Out:
#   spare_parts  quantity  costs  sale_price       date total_revenue
# 0       Wheel        24     30          53  1 01 2020        $1,272
# 1        Tyre        20     80         110  2 01 2020        $2,200
# 2     Battery        46     85          95  3 01 2020        $4,370
# 3  Air Filter        37     36          48  4 01 2020        $1,776
# 4  Oil Filter        28     96         120  5 01 2020        $3,360

# %%
df[["date","total_revenue"]].dtypes
# Out:
# date             object
# total_revenue    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# spare_parts      0
# quantity         0
# costs            0
# sale_price       0
# date             0
# total_revenue    0
# dtype: int64

# %%
df["spare_parts"].duplicated().sum()
# Out:
# np.int64(10)

# %%
df["total_revenue"] = df["total_revenue"].replace(",","",regex=True)

df["total_revenue"] = df["total_revenue"].str.replace("$", "").astype(int)
df.head()
# Out:
#   spare_parts  quantity  costs  sale_price       date  total_revenue
# 0       Wheel        24     30          53  1 01 2020           1272
# 1        Tyre        20     80         110  2 01 2020           2200
# 2     Battery        46     85          95  3 01 2020           4370
# 3  Air Filter        37     36          48  4 01 2020           1776
# 4  Oil Filter        28     96         120  5 01 2020           3360

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
plt.hist(df['total_revenue'], bins = 10)
plt.xlabel("Total Sales")
plt.ylabel("Frequency")
plt.title("Distribution of Total Sales", fontsize = 20)
plt.show()

# %% [markdown]
# 2. Boxplots are useful for identifying outliers, visualizing the median, quartiles, and range of the dataset, and comparing the distributions of different groups or categories within the dataset. Use a box plot of the seaborn library to compare the distribution of total sales for each item.

# %%
import seaborn as sns

plt.subplots(figsize=(15, 8))

sns.boxplot(x="spare_parts", y="total_revenue", 
            data=df,  
            width=0.2, 
            linewidth=1.0 )
            
plt.title("Total Sales Distribution by Item", fontsize= 20)
plt.show()

# %% [markdown]
# 3. Use a Matplotlib scatter plot to visualize the relationship between price and total sales for each item. Can you identify on the graph which product brought in the most income?

# %%
import numpy as np
grouped_sales = df.groupby("spare_parts")["total_revenue"].sum()

fig, ax = plt.subplots(figsize=(15, 10))
colors = np.random.rand(10)
plt.scatter( grouped_sales.index,grouped_sales, c=colors, alpha=1.0)
plt.xlabel(xlabel="Total Revenue")
plt.ylabel(ylabel= "Spare parts")
plt.title("Products Analysis", fontsize= 30)
plt.show()

# %% [markdown]
# 4. Filter the DataFrame to return only columns with integer data type. Save this to a new variable.

# %%
df2 = df.select_dtypes(include='int')
df2.head()
# Out:
#    quantity  costs  sale_price  total_revenue
# 0        24     30          53           1272
# 1        20     80         110           2200
# 2        46     85          95           4370
# 3        37     36          48           1776
# 4        28     96         120           3360

# %% [markdown]
# 5. What is the most profitable and least profitable product? What is the difference in profit between the most profitable and the least profitable product? By how what percentage, will the total profit drop if the least profitable product was dropped?

# %%
df["total_costs"] = df["costs"] * df["quantity"]
df["profit"] = df["total_revenue"] - df["total_costs"]
df.head()
# Out:
#   spare_parts  quantity  costs  sale_price       date  total_revenue  \
# 0       Wheel        24     30          53  1 01 2020           1272
# 1        Tyre        20     80         110  2 01 2020           2200
# 2     Battery        46     85          95  3 01 2020           4370
# 3  Air Filter        37     36          48  4 01 2020           1776
# 4  Oil Filter        28     96         120  5 01 2020           3360
#
#    total_costs  profit
# 0          720     552
# 1         1600     600
# 2         3910     460
# 3         1332     444
# 4         2688     672

# %%
df_group = df.groupby("spare_parts")[["profit"]].sum()

most_profitable_product = df_group.loc[:,"profit"].idxmax()

least_profitable_product = df_group.loc[:,"profit"].idxmin()
print(f'The most profitable product is: {most_profitable_product}')
print(f'The least profitable product is: {least_profitable_product}')
# Out:
# The most profitable product is: Timing Belt
# The least profitable product is: Air Filter

# %%
max_value_row = df_group.loc[df_group['profit'].idxmax()]

min_value_row = df_group.loc[df_group['profit'].idxmin()]

difference_in_profit = max_value_row - min_value_row
print("Profit difference between the most profitable and least profitable "
       "product is", difference_in_profit[0])
# Out:
# Profit difference between the most profitable and least profitable product is 1556
# C:\Users\Ashmeet\AppData\Local\Temp\ipykernel_16848\2217191804.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   "product is", difference_in_profit[0])

# %%
total_profit = df_group["profit"].sum()

least_profitable_profit = df_group["profit"].min()

percentage_drop = least_profitable_profit/total_profit*100
print(f'{percentage_drop:.2f}%')
# Out:
# 5.77%

# %% [markdown]
# 6. Use a 3D scatter plot to visualize the relationship between price, quantity, and total sales for each item.

# %%
fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(111, projection='3d')

# Plot the data using the scatter() method
ax.scatter(df['sale_price'], 
           df['quantity'], 
           df['costs'],
           alpha=1.0)

# Add labels to the axes
ax.set_xlabel('sale_price')
ax.set_ylabel('quantity')
ax.set_zlabel('costs')
plt.title("Price vs Quantity vs Costs", fontsize= 20)
plt.show()

# %% [markdown]
# 7. The sns pairplot is a very important tool for visualizing relationship between variables in a data set. Use the pairplot to plot to visualize the relationship of all the variables in the dataset.

# %%
sns.pairplot(df, hue="spare_parts")
plt.show()

# %% [markdown]
# 8. Use a seaborn barplot to visualize the distribution of quantities for each item.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15, 10))
sns.barplot(x="spare_parts",y = "quantity", data = df)
plt.title("Products Quantity Analysis", fontsize = 30)
plt.show()

# %% [markdown]
# 9. Use a Seaborn lineplot to visualize the trend of total sales over time for all items combined.

# %%
df["date"] = pd.to_datetime(df["date"])

df_group = df.groupby("date")["total_revenue"].sum()

fig = plt.figure(figsize=(12, 8))
sns.lineplot(x=df_group.index, y=df_group.values)
plt.title("Revenue Trend", fontsize=30)
plt.show()

# %% [markdown]
# 10. Use a Seaborn lmplot to fit a linear regression model and visualize the relationship between price and total revenue. Your plot should have a white grid style and a height of 8.

# %%
sns.lmplot(x = "sale_price",
           y = "total_revenue",
           fit_reg=True,
           height = 8,
           data=df) 
sns.set_style("whitegrid", {'axes.grid' : False})
plt.title("Price and Total Revenue Relationship", fontsize = 20)
plt.show()
