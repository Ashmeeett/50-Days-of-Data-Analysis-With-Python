# %% [markdown]
# 1. Using the data above, create an array and transpose it. The creating of an array and transposition should be combined into one code. The code should return a transposed array.

# %%
import numpy as np

names = ["John", "Kelly", "Jos", "Peter", "Robert", "Piper"]
age = [21, 21, 56, 44, 56, 96]
gender = ['m', 'f', 'm', 'm', 'm', 'f']

# creating an array and transposing
array1= np.array([names, age, gender]).transpose()
array1
# Out:
# array([['John', '21', 'm'],
#        ['Kelly', '21', 'f'],
#        ['Jos', '56', 'm'],
#        ['Peter', '44', 'm'],
#        ['Robert', '56', 'm'],
#        ['Piper', '96', 'f']], dtype='<U21')

# %% [markdown]
# 2. Using slicing or indexing, write a code to return the last row of the transposed array (question 1).

# %%
last_row_array = array1[-1]
last_row_array
# Out:
# array(['Piper', '96', 'f'], dtype='<U21')

# %% [markdown]
# 3. Using slicing or indexing, write a code to return the first two rows of the transposed array (question 1).

# %%
slice_two_rows = array1[:2]
slice_two_rows
# Out:
# array([['John', '21', 'm'],
#        ['Kelly', '21', 'f']], dtype='<U21')

# %% [markdown]
# 4. Using slicing, write a code that returns the age of Peter. Return Peter’s age as an integer data type.

# %%
peter_age = int(array1[3,1])
print(f'Peter is {peter_age} yrs old')
# Out:
# Peter is 44 yrs old

# %% [markdown]
# 5. Write code to return an array of Kelly's age and gender using slicing (from transposed array in question 1).

# %%
kelly_age_gender = array1[1, 1:3]
kelly_age_gender
# Out:
# array(['21', 'f'], dtype='<U21')

# %% [markdown]
# 6. One of the uses of slicing is for Data visualization: Slicing is often used in data visualization to extract specific portions of a dataset for plotting. Write a code to create a subarray of the ages(only ages) in the transposed array using slicing. Using Matplotlib, plot a histogram of the age array. Your graph we should have xlabel, ylabel and a title.

# %%
age_array = array1[:,1]
age_array
# Out:
# array(['21', '21', '56', '44', '56', '96'], dtype='<U21')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
plt.hist(age_array, rwidth = 2.9, bins= 10)
plt.xlabel("age")
plt.ylabel("Frequency")
plt.title("Age Distribution", fontsize= 20)
plt.show()
