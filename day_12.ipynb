# %% [markdown]
# 1. Create an array using the list above. Write a code to sort the array in ascending order; first sort by columns, then by rows. Create a new variable for each of the sorted arrays.

# %%
import numpy as np

list1 = [[12, 34, 56], [12, 13, 8], [6, 5, 10]]

# Creating array from list
array1 = np.array(list1)

# Sort the array in ascending order by columns
sorted_array_column = np.sort(array1, axis = 0)
sorted_array_column
# Out:
# array([[ 6,  5,  8],
#        [12, 13, 10],
#        [12, 34, 56]])

# %%
list1 = [[12, 34, 56], [12, 13, 8], [6, 5, 10]]

# Creating array from list
array1 = np.array(list1)

# Sort array in ascending order by rows
sorted_array_row = np.sort(array1, axis=1)
sorted_array_row
# Out:
# array([[12, 34, 56],
#        [ 8, 12, 13],
#        [ 5,  6, 10]])

# %% [markdown]
# 2. Using NumPy slicing, write a code that slices these numbers in this order [8, 12, 56] from the array sorted by columns (question 1 ). Create a new variable.

# %%
new_array = np.array([sorted_array_column[0][2], 
                      sorted_array_column[1][0], 
                      sorted_array_column[2][2]]
                    )
new_array
# Out:
# array([ 8, 12, 56])

# %% [markdown]
# 3. Create a 2-dimensional array of random integers between 100 and -100 of shape (3, 3). Use numpy.where() function to replace all negative values in the array with 0. Use seed to save the random numbers generated.

# %%
# Generating data
rng = np.random.default_rng(seed = 42)
array2 = rng.integers(low = -100, high = 100, size=(3, 3))
array2
# Out:
# array([[-83,  54,  30],
#        [-13, -14,  71],
#        [-83,  39, -60]])

# %%
array2 = np.where(array2 < 0, 0, array2)
array2
# Out:
# array([[ 0, 54, 30],
#        [ 0,  0, 71],
#        [ 0, 39,  0]])

# %% [markdown]
# 4. Here is a list below:
# list1 = [[12, 23, 34, 34], [13, 13, 20, 21]]
# Create an array from the list above.
# Using np.unique() function, return the unique elements in a the array and return the counts of each unique element (how many times each element appears in the list).

# %%
list1 = [[12, 23, 34, 34, 35], [13, 13, 13, 20, 21]]

array3 = np.array(list1)

unique_elements, elements_count = np.unique(array3, return_counts=True)

print("Unique Elements:", unique_elements)
print("Elements count:", elements_count)
# Out:
# Unique Elements: [12 13 20 21 23 34 35]
# Elements count: [1 3 1 1 1 2 1]

# %% [markdown]
# 5. Using the np.flatten() function to flatten the nested array you created in question 4.

# %%
array4 = array3.flatten()
array4
# Out:
# array([12, 23, 34, 34, 35, 13, 13, 13, 20, 21])
